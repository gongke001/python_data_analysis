# %% [markdown]
# # 项目：评估和清理K-Pop偶像数据集

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析的目的是，根据K-Pop偶像信息，通过人口统计学分析，揭示韩国娱乐产业在偶像选拔和公司战略中的系统性规律。例如男女偶像在身高、体重、BMI等生理指标上的选拔标准差异、头部娱乐公司（SM/JYP/YG）是否存在差异化的审美标准、出道年龄随年代推移是否有改变以及外籍偶像的分布等。
#
# 本实战项目的目的在于练习评估数据干净和整洁度，并且基于评估结果，对数据进行清洗，从而得到可供下一步分析的数据。

# %% [markdown]
# ## 简介

# %% [markdown]
# 原始数据集提供了1700多位K-Pop（韩流）偶像的信息，包括他们的艺名、全名、韩文名、性别、出生日期、身高、体重、出生地以及之前和其他团体的关联。

# %% [markdown]
# 数据每列的含义如下：
# - `Stage Name`：偶像被熟知的舞台上名字，即艺名。同一个团体不会有相同艺名的偶像。
# - `Full Name`：偶像的全名
# - `Korean Name`：偶像的韩文名字
# - `K Stage Name`：偶像的韩文舞台名字，同一个团体不会有相同韩文舞台名字的偶像。
# - `Date of Birth`：偶像的出生日期
# - `Group`：偶像所属的韩流团体
# - `Debut`：偶像出道的日期
# - `Company`：偶像所属娱乐公司
# - `Country`：偶像的原籍国家
# - `Second Country`：偶像的第二个国家（如果有的话）
# - `Height`：偶像的身高
# - `Weight`：偶像的体重
# - `Birthplace`：偶像的出生地
# - `Other Group`：偶像所属的其他团体，这个可能是更改后的团体名或者原团体的小分队
# - `Former Group`：偶像所属的前一个韩流团体
# - `Gender`：偶像的性别

# %% [markdown]
# ## 读取数据

# %% [markdown]
# 首先导入数据分析需要的pandas库，通过pandas库的`read_csv`函数读取原始文件`"kpop_idols.csv"`，将其解析为DataFrame，并赋值给变量`original_data`。查看该DataFrame的前五行数据。

# %%
import pandas as pd

# %%
original_data=pd.read_csv("kpop_idols.csv")

# %%
original_data.head()
# Out:
#   Stage Name      Full Name Korean Name K Stage Name Date of Birth      Group  \
# 0      2Soul  Kim Younghoon         김영훈           이솔    10/09/1997  7 O'clock
# 1        A.M  Seong Hyunwoo         성현우          에이엠    31/12/1996  Limitless
# 2        Ace  Jang Wooyoung         장우영          에이스    28/08/1992        VAV
# 3       Aeji      Kwon Aeji         권애지           애지    25/10/1999   Hash Tag
# 4       AhIn       Lee Ahin         이아인           아인    27/09/1999   MOMOLAND
#
#         Debut      Company      Country Second Country  Height  Weight  \
# 0  26/08/2014       Jungle  South Korea            NaN   172.0    55.0
# 1   9/07/2019          ONO  South Korea            NaN   181.0    62.0
# 2  31/10/2015       A team  South Korea            NaN   177.0    63.0
# 3  11/10/2017          LUK  South Korea            NaN   163.0     NaN
# 4   9/11/2016  Double Kick  South Korea            NaN   160.0    44.0
#
#   Birthplace Other Group Former Group Gender
# 0        NaN         NaN          NaN      M
# 1        NaN         NaN          NaN      M
# 2        NaN         NaN          NaN      M
# 3      Daegu         NaN          NaN      F
# 4      Wonju         NaN          NaN      F

# %% [markdown]
# ## 评估数据

# %% [markdown]
# 第二步是针对上一步建立的`original_data`这个DataFrame所包含的数据进行评估。
#
# 数据评估将从两个方面进行：结构和内容，即整齐度和干净度。数据结构性问题是指不符合“1.每一列是一个变量，2.每一行是一个观测值，3.每个单元格是一个值”的标准；数据内容性的问题包括存在丢失数据、重复数据和无效数据等情况。

# %% [markdown]
# ### 评估数据整齐度

# %%
original_data.sample(n=10, random_state=30)
# Out:
#      Stage Name       Full Name Korean Name K Stage Name Date of Birth  \
# 1741       Yuna        Seo Yuna         서유나           유나    30/12/1992
# 1117      Ni-Ki  Nishimura Riki     니시무라 리키           니키     9/12/2005
# 426       Hanse        Do Hanse         도한세           한세    25/09/1997
# 1080      Muzin     Kim Hyunwoo         김현우           무진    29/03/2001
# 1486       The8      Xu Minghao        쉬밍하오          디에잇     7/11/1997
# 197      Damhee     Park Damhee         박담희           담희    21/06/2000
# 706        JinE     Shin Hyejin         신혜진           진이    22/01/1995
# 314      Eunice     Heo Sooyeon         허수연          유니스     2/09/1991
# 1190       Ruka      Kawai Ruka      카와이 루카           루카    20/03/2002
# 1677       Yoon       Ji Hayoon         지하윤            윤     8/07/1997
#
#             Group       Debut       Company      Country Second Country  \
# 1741          AoA  30/07/2012           FNC  South Korea            NaN
# 1117      ENHYPEN  30/11/2020       Be:lift        Japan            NaN
# 426        VICTON   9/11/2016        Plan A  South Korea            NaN
# 1080       BAE173  19/11/2020     PocketDol  South Korea            NaN
# 1486    Seventeen  26/05/2015        Pledis        China            NaN
# 197       ARTBEAT  16/11/2022   AB Creative  South Korea            NaN
# 706           NaN         NaN           NaN  South Korea            NaN
# 314           DIA  14/07/2015           MBK  South Korea            NaN
# 1190  BABYMONSTER   0/01/1900            YG        Japan            NaN
# 1677        Gate9  26/01/1999  JYP| SidusHQ  South Korea            NaN
#
#       Height  Weight Birthplace Other Group Former Group Gender
# 1741   163.0    45.0      Busan   AOA BLACK          NaN      F
# 1117     NaN     NaN        NaN         NaN          NaN      M
# 426      NaN     NaN        NaN         NaN          NaN      M
# 1080     NaN     NaN        NaN         NaN          NaN      M
# 1486   175.0    53.0     Anshan         NaN          NaN      M
# 197      NaN     NaN        NaN         NaN          NaN      F
# 706    160.0    48.0     Pohang         NaN   Oh My Girl      F
# 314    166.0    49.0      Busan         NaN          NaN      F
# 1190     NaN     NaN        NaN         NaN          NaN      F
# 1677   162.0     NaN      Busan         NaN          NaN      F

# %% [markdown]
# 抽取10条样本观察，数据不符合“1.每一列是一个变量，2.每一行是一个观测值，3.每个单元格是一个值”的标准。具体来看，每一行是一位具体的偶像，每一列是关于某位偶像的基本信息的变量。但是可以看到索引`1677`的行中，`Company`变量有2个值。这是由于偶像可能在合约到期后签约新公司（也有合约到期前解约的情况，但普遍代价较大，不算是普适情况）。
#
# `Company`变量数据不符合“单元格为一个值的标准”，需要把此列进行拆分。由于本次分析目的之一是公司在选拔偶像上是否有差异化标准，我们只保留偶像第一次出道的公司，从最初的选拔上进行研究，需要删除后续所属公司的列。

# %% [markdown]
# ### 评估数据干净度

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1778 entries, 0 to 1777
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Stage Name      1778 non-null   object
#  1   Full Name       1769 non-null   object
#  2   Korean Name     1768 non-null   object
#  3   K Stage Name    1777 non-null   object
#  4   Date of Birth   1776 non-null   object
#  5   Group           1632 non-null   object
#  6   Debut           1632 non-null   object
#  7   Company         1632 non-null   object
#  8   Country         1778 non-null   object
#  9   Second Country  62 non-null     object
#  10  Height          836 non-null    float64
#  11  Weight          566 non-null    float64
#  12  Birthplace      834 non-null    object
#  13  Other Group     140 non-null    object
#  14  Former Group    264 non-null    object
#  15  Gender          1778 non-null   object
# dtypes: float64(2), object(14)
# memory usage: 222.4+ KB

# %% [markdown]
# 从输出结果来看，数据共有1778条观察值，其中`Stage Name`、`Country`、`Gender`不存在缺失值，其他变量均存在缺失值；`Date of Birth`、`Debut`应该为日期类型，`Gender`最好为`category`类型，需要进行格式转换。

# %% [markdown]
# #### 评估缺失数据

# %% [markdown]
# 在了解`Full Name`等变量存在缺失值后，根据条件提取各个变量的缺失值。
#
# 其中`Second Country`、`Birthplace`、`Other Group`、`Former Group`缺失值较多，但这四个变量都不会影响到分析结果，可以直接删除列。

# %% [markdown]
# 如果`Stage name`和`Full name`、`Korean name`、`K Stage name`同时缺失，可能该记录无效，但是我们通过`describe`方法已经了解到`Stage name`不存在缺失值，同时这三个变量也不会对分析结果产生任何影响，因此这三列可以在后续步骤中删除。

# %% [markdown]
# 下面针对本次分析使用到的关键变量，进行缺失值的提取。

# %% [markdown]
# 对`Date of Birth`根据条件提取缺失值。

# %%
original_data[original_data["Date of Birth"].isnull()]
# Out:
#      Stage Name    Full Name Korean Name K Stage Name Date of Birth  Group  \
# 1127         On  Kim Dongwoo         김동우            온           NaN  ABLUE
# 1172        Roa          NaN         NaN           로아           NaN   X:IN
#
#            Debut Company      Country Second Country  Height  Weight  \
# 1127  23/10/2022  J-Star  South Korea            NaN   177.0    65.0
# 1172  11/04/2023  Escrow  South Korea            NaN     NaN     NaN
#
#      Birthplace Other Group Former Group Gender
# 1127        NaN         NaN          NaN      M
# 1172        NaN         NaN          NaN      F

# %% [markdown]
# `Date of Birth`是进行后续偶像特征分析的重要变量。如果缺失或者无效，那么认为该数据无法提供有效含义，因此后续可以删除`Date of Birth`的缺失值。

# %% [markdown]
# 对`Group`根据条件提取缺失值。

# %%
original_data[original_data["Group"].isnull()]
# Out:
#      Stage Name      Full Name Korean Name K Stage Name Date of Birth Group  \
# 11        Ailee      Lee Yejin         이예진          에일리    30/05/1989   NaN
# 12         Aini    Kim Heejung         김희정          아이니    13/07/1991   NaN
# 16        AleXa       Kim Seri         김세리          알렉사     6/12/1996   NaN
# 29        Arang     Son Mnjung         손민정           아랑     8/03/2000   NaN
# 46          B.I     Kim Hanbin         김한빈          비아이    22/10/1996   NaN
# ...         ...            ...         ...          ...           ...   ...
# 1708   Youngmin   Lim Youngmin         임영민           영민    25/12/1995   NaN
# 1714      Yubin      Cho Yubin         조유빈           유빈     9/10/1999   NaN
# 1725    Yujeong    Kim Yujeong         김유정           유정    14/02/1992   NaN
# 1740     Yulhee     Kim Yulhee         김율희           율희    27/11/1997   NaN
# 1776       Z-UK  Jeong Jaewook         정재욱           지욱    27/01/1993   NaN
#
#      Debut Company      Country Second Country  Height  Weight Birthplace  \
# 11     NaN     NaN  South Korea            USA   165.0     NaN     Denver
# 12     NaN     NaN  South Korea            NaN   163.0    44.0        NaN
# 16     NaN     NaN          USA            NaN     NaN     NaN        NaN
# 29     NaN     NaN  South Korea            NaN     NaN     NaN        NaN
# 46     NaN     NaN  South Korea            NaN     NaN     NaN     Goyang
# ...    ...     ...          ...            ...     ...     ...        ...
# 1708   NaN     NaN  South Korea            NaN     NaN     NaN      Busan
# 1714   NaN     NaN  South Korea            NaN   156.0    40.0        NaN
# 1725   NaN     NaN  South Korea            NaN   161.0    42.0      Seoul
# 1740   NaN     NaN  South Korea            NaN   166.0    52.0    Bucheon
# 1776   NaN     NaN  South Korea            NaN   174.0    62.0        NaN
#
#      Other Group  Former Group Gender
# 11           NaN           NaN      F
# 12           NaN  Pink Fantasy      F
# 16           NaN           NaN      F
# 29           NaN     NeonPunch      F
# 46           NaN          iKON      M
# ...          ...           ...    ...
# 1708         MXM         AB6IX      M
# 1714         NaN  Pink Fantasy      F
# 1725         NaN        LABOUM      F
# 1740         NaN        LABOUM      F
# 1776         NaN        Bigflo      M
#
# [146 rows x 16 columns]

# %% [markdown]
# 从输出结果来看，`Group`变量缺失的数据对应的`Debut`和`Company`也是都缺失的。为了验证猜想，增加条件进行筛选。

# %%
original_data[(original_data["Group"].isnull())&(original_data["Debut"].notna())]
# Out:
# Empty DataFrame
# Columns: [Stage Name, Full Name, Korean Name, K Stage Name, Date of Birth, Group, Debut, Company, Country, Second Country, Height, Weight, Birthplace, Other Group, Former Group, Gender]
# Index: []

# %%
original_data[(original_data["Group"].isnull())&(original_data["Company"].notna())]
# Out:
# Empty DataFrame
# Columns: [Stage Name, Full Name, Korean Name, K Stage Name, Date of Birth, Group, Debut, Company, Country, Second Country, Height, Weight, Birthplace, Other Group, Former Group, Gender]
# Index: []

# %% [markdown]
# 输出结果数量为0，可以验证猜想是正确的。说明`Group`变量缺失的数据，对应的`Debut`和`Company`也都是缺失的。
# `Debut`和`Company`是分析偶像出道年龄和公司标准差异的关键变量，如果同时缺失或者失效，则认为不能为分析提供有效的数据，所以在后续清理步骤中应该删除`Group`变量缺失数据。

# %% [markdown]
# 对`Debut`根据条件提取缺失值。

# %%
original_data[original_data["Debut"].isnull()]
# Out:
#      Stage Name      Full Name Korean Name K Stage Name Date of Birth Group  \
# 11        Ailee      Lee Yejin         이예진          에일리    30/05/1989   NaN
# 12         Aini    Kim Heejung         김희정          아이니    13/07/1991   NaN
# 16        AleXa       Kim Seri         김세리          알렉사     6/12/1996   NaN
# 29        Arang     Son Mnjung         손민정           아랑     8/03/2000   NaN
# 46          B.I     Kim Hanbin         김한빈          비아이    22/10/1996   NaN
# ...         ...            ...         ...          ...           ...   ...
# 1708   Youngmin   Lim Youngmin         임영민           영민    25/12/1995   NaN
# 1714      Yubin      Cho Yubin         조유빈           유빈     9/10/1999   NaN
# 1725    Yujeong    Kim Yujeong         김유정           유정    14/02/1992   NaN
# 1740     Yulhee     Kim Yulhee         김율희           율희    27/11/1997   NaN
# 1776       Z-UK  Jeong Jaewook         정재욱           지욱    27/01/1993   NaN
#
#      Debut Company      Country Second Country  Height  Weight Birthplace  \
# 11     NaN     NaN  South Korea            USA   165.0     NaN     Denver
# 12     NaN     NaN  South Korea            NaN   163.0    44.0        NaN
# 16     NaN     NaN          USA            NaN     NaN     NaN        NaN
# 29     NaN     NaN  South Korea            NaN     NaN     NaN        NaN
# 46     NaN     NaN  South Korea            NaN     NaN     NaN     Goyang
# ...    ...     ...          ...            ...     ...     ...        ...
# 1708   NaN     NaN  South Korea            NaN     NaN     NaN      Busan
# 1714   NaN     NaN  South Korea            NaN   156.0    40.0        NaN
# 1725   NaN     NaN  South Korea            NaN   161.0    42.0      Seoul
# 1740   NaN     NaN  South Korea            NaN   166.0    52.0    Bucheon
# 1776   NaN     NaN  South Korea            NaN   174.0    62.0        NaN
#
#      Other Group  Former Group Gender
# 11           NaN           NaN      F
# 12           NaN  Pink Fantasy      F
# 16           NaN           NaN      F
# 29           NaN     NeonPunch      F
# 46           NaN          iKON      M
# ...          ...           ...    ...
# 1708         MXM         AB6IX      M
# 1714         NaN  Pink Fantasy      F
# 1725         NaN        LABOUM      F
# 1740         NaN        LABOUM      F
# 1776         NaN        Bigflo      M
#
# [146 rows x 16 columns]

# %% [markdown]
# `Debut`是分析偶像出道年龄关键变量，如果缺失或者失效，则认为不能为分析提供有效的数据，所以在后续清理步骤中应该删除`Debut`变量缺失数据。

# %% [markdown]
# 对`Company`根据条件提取缺失值。

# %%
original_data[original_data["Company"].isnull()]
# Out:
#      Stage Name      Full Name Korean Name K Stage Name Date of Birth Group  \
# 11        Ailee      Lee Yejin         이예진          에일리    30/05/1989   NaN
# 12         Aini    Kim Heejung         김희정          아이니    13/07/1991   NaN
# 16        AleXa       Kim Seri         김세리          알렉사     6/12/1996   NaN
# 29        Arang     Son Mnjung         손민정           아랑     8/03/2000   NaN
# 46          B.I     Kim Hanbin         김한빈          비아이    22/10/1996   NaN
# ...         ...            ...         ...          ...           ...   ...
# 1708   Youngmin   Lim Youngmin         임영민           영민    25/12/1995   NaN
# 1714      Yubin      Cho Yubin         조유빈           유빈     9/10/1999   NaN
# 1725    Yujeong    Kim Yujeong         김유정           유정    14/02/1992   NaN
# 1740     Yulhee     Kim Yulhee         김율희           율희    27/11/1997   NaN
# 1776       Z-UK  Jeong Jaewook         정재욱           지욱    27/01/1993   NaN
#
#      Debut Company      Country Second Country  Height  Weight Birthplace  \
# 11     NaN     NaN  South Korea            USA   165.0     NaN     Denver
# 12     NaN     NaN  South Korea            NaN   163.0    44.0        NaN
# 16     NaN     NaN          USA            NaN     NaN     NaN        NaN
# 29     NaN     NaN  South Korea            NaN     NaN     NaN        NaN
# 46     NaN     NaN  South Korea            NaN     NaN     NaN     Goyang
# ...    ...     ...          ...            ...     ...     ...        ...
# 1708   NaN     NaN  South Korea            NaN     NaN     NaN      Busan
# 1714   NaN     NaN  South Korea            NaN   156.0    40.0        NaN
# 1725   NaN     NaN  South Korea            NaN   161.0    42.0      Seoul
# 1740   NaN     NaN  South Korea            NaN   166.0    52.0    Bucheon
# 1776   NaN     NaN  South Korea            NaN   174.0    62.0        NaN
#
#      Other Group  Former Group Gender
# 11           NaN           NaN      F
# 12           NaN  Pink Fantasy      F
# 16           NaN           NaN      F
# 29           NaN     NeonPunch      F
# 46           NaN          iKON      M
# ...          ...           ...    ...
# 1708         MXM         AB6IX      M
# 1714         NaN  Pink Fantasy      F
# 1725         NaN        LABOUM      F
# 1740         NaN        LABOUM      F
# 1776         NaN        Bigflo      M
#
# [146 rows x 16 columns]

# %% [markdown]
# `Company`是分析娱乐公司标准差异的关键变量，如果缺失或者失效，则认为不能为分析提供有效的数据，所以在后续清理步骤中应该删除`Company`变量缺失数据。

# %% [markdown]
# 对`Height`根据条件提取缺失值。

# %%
original_data[original_data["Height"].isnull()]
# Out:
#      Stage Name       Full Name Korean Name K Stage Name Date of Birth  \
# 5          Ahra         Go Ahra         고아라           아라    21/02/2001
# 6        Ahyeon     Jung Ahyeon         정아현           아현    11/04/2007
# 7        Ahyoon      Choi Subin         최수빈           아윤    23/10/2004
# 8        Ahyoon     Shin Ahyoon         신아윤           아윤    24/09/2003
# 9       Ahyoung     Cho Jayoung         조자영           아영    26/05/1991
# ...         ...             ...         ...          ...           ...
# 1766         YY    Kim Moonyong         김문용         와이와이    30/08/1991
# 1768       Zero  Nasukawa Shota     나스카와 쇼타           제로    20/01/2003
# 1771        Zin     Jin Hyunbin         진현빈           지인    31/08/2001
# 1775       Zuho        Bae Juho         백주호           주호     4/07/1996
# 1777       Zuny       Kim Joomi         김주미           주니     8/12/1994
#
#              Group       Debut       Company      Country Second Country  \
# 5         Favorite   5/07/2017        Astory  South Korea            NaN
# 6      BABYMONSTER   0/01/1900            YG  South Korea            NaN
# 7         BOTOPASS  26/08/2020       WKS ENE  South Korea            NaN
# 8       Queenz Eye  24/10/2022  Big Mountain  South Korea            NaN
# 9       Dal Shabet   3/01/2011    Happy Face  South Korea            NaN
# ...            ...         ...           ...          ...            ...
# 1766          UNVS  23/02/2020        CHITWN  South Korea            NaN
# 1768         T1419  21/09/2007        CJ E&M        Japan            NaN
# 1771       bugAboo  25/10/2021        A team  South Korea            NaN
# 1775           SF9   5/10/2016           FNC  South Korea            NaN
# 1777  Ladies' Code   7/03/2013       Polaris  South Korea            NaN
#
#       Height  Weight Birthplace Other Group Former Group Gender
# 5        NaN     NaN      Yeosu         NaN          NaN      F
# 6        NaN     NaN        NaN         NaN          NaN      F
# 7        NaN     NaN        NaN         NaN          NaN      F
# 8        NaN     NaN      Seoul         NaN          NaN      F
# 9        NaN     NaN      Seoul         NaN          NaN      F
# ...      ...     ...        ...         ...          ...    ...
# 1766     NaN     NaN        NaN         NaN          NaN      M
# 1768     NaN     NaN        NaN         NaN          NaN      M
# 1771     NaN     NaN        NaN         NaN          NaN      F
# 1775     NaN     NaN        NaN         NaN          NaN      M
# 1777     NaN     NaN    Gwangju         NaN          NaN      F
#
# [942 rows x 16 columns]

# %% [markdown]
# 从输出结果来看，`Height`变量缺失数据较多，由于`Height`变量是分析的关键变量，所以按照性别分组中位数对缺失数据进行填充。

# %% [markdown]
# 对`Weight`根据条件提取缺失值。

# %%
original_data[original_data["Weight"].isnull()]
# Out:
#      Stage Name       Full Name Korean Name K Stage Name Date of Birth  \
# 3          Aeji       Kwon Aeji         권애지           애지    25/10/1999
# 5          Ahra         Go Ahra         고아라           아라    21/02/2001
# 6        Ahyeon     Jung Ahyeon         정아현           아현    11/04/2007
# 7        Ahyoon      Choi Subin         최수빈           아윤    23/10/2004
# 8        Ahyoon     Shin Ahyoon         신아윤           아윤    24/09/2003
# ...         ...             ...         ...          ...           ...
# 1768       Zero  Nasukawa Shota     나스카와 쇼타           제로    20/01/2003
# 1771        Zin     Jin Hyunbin         진현빈           지인    31/08/2001
# 1774        Zoa      Cho Hyewon         조혜원           조아    31/05/2005
# 1775       Zuho        Bae Juho         백주호           주호     4/07/1996
# 1777       Zuny       Kim Joomi         김주미           주니     8/12/1994
#
#              Group       Debut       Company      Country Second Country  \
# 3         Hash Tag  11/10/2017           LUK  South Korea            NaN
# 5         Favorite   5/07/2017        Astory  South Korea            NaN
# 6      BABYMONSTER   0/01/1900            YG  South Korea            NaN
# 7         BOTOPASS  26/08/2020       WKS ENE  South Korea            NaN
# 8       Queenz Eye  24/10/2022  Big Mountain  South Korea            NaN
# ...            ...         ...           ...          ...            ...
# 1768         T1419  21/09/2007        CJ E&M        Japan            NaN
# 1771       bugAboo  25/10/2021        A team  South Korea            NaN
# 1774       Weeekly  30/07/2020        Play M  South Korea            NaN
# 1775           SF9   5/10/2016           FNC  South Korea            NaN
# 1777  Ladies' Code   7/03/2013       Polaris  South Korea            NaN
#
#       Height  Weight Birthplace Other Group Former Group Gender
# 3      163.0     NaN      Daegu         NaN          NaN      F
# 5        NaN     NaN      Yeosu         NaN          NaN      F
# 6        NaN     NaN        NaN         NaN          NaN      F
# 7        NaN     NaN        NaN         NaN          NaN      F
# 8        NaN     NaN      Seoul         NaN          NaN      F
# ...      ...     ...        ...         ...          ...    ...
# 1768     NaN     NaN        NaN         NaN          NaN      M
# 1771     NaN     NaN        NaN         NaN          NaN      F
# 1774   170.0     NaN        NaN         NaN          NaN      F
# 1775     NaN     NaN        NaN         NaN          NaN      M
# 1777     NaN     NaN    Gwangju         NaN          NaN      F
#
# [1212 rows x 16 columns]

# %% [markdown]
# 从输出结果来看，`Weight`变量缺失数据较多，由于`Weight`变量是分析的关键变量，所以按照性别分组中位数对缺失数据进行填充。

# %% [markdown]
# #### 评估重复数据

# %% [markdown]
# 根据数据变量的含义来看，该数据集的变量都不是唯一标识，但是依据行业常规，相同的团体中是不会出现相同艺名的偶像的，也就是`Group`变量和`Stage Name`不可以同时出现相同的值。

# %% [markdown]
# 首先针对`Stage Name`进行重复值的检查。

# %%
original_data["Stage Name"].value_counts().sort_index()
# Out:
# 2Soul    1
# A-min    1
# A-ra     1
# A.M      1
# Ace      1
#         ..
# Ziu      1
# Zoa      1
# Zuho     1
# Zuny     1
# ra.L     1
# Name: Stage Name, Length: 1469, dtype: int64

# %% [markdown]
# 输出结果数量为1469，比数据集的记录1778少，并且已知`Stage Name`不存在缺失值，所以`Stage Name`变量存在重复值。接下来提取`Stage Name`的重复值。

# %%
original_data[original_data["Stage Name"].duplicated(keep=False)]
# Out:
#      Stage Name       Full Name Korean Name K Stage Name Date of Birth  \
# 7        Ahyoon      Choi Subin         최수빈           아윤    23/10/2004
# 8        Ahyoon     Shin Ahyoon         신아윤           아윤    24/09/2003
# 17        Alice     Song Joohee         송주희          앨리스    21/03/1990
# 18        Alice  Cheon Jaeyoung         천재영          앨리스    20/02/2002
# 22         Andy   Lui Chunyeung        루이쯔양           앤디     6/10/1994
# ...         ...             ...         ...          ...           ...
# 1744       Yuna       Shin Yuna         신유나           유나     9/12/2003
# 1747      Yunji       Kim Yunji         김윤지           윤지    26/08/1996
# 1748      Yunji       Lee Yunji         이윤지           윤지     4/04/1992
# 1758       Yuri         Jo Yuri         조유리           유리    22/10/2001
# 1759       Yuri       Kwon Yuri        권유리            유리     5/12/1989
#
#             Group       Debut         Company      Country Second Country  \
# 7        BOTOPASS  26/08/2020         WKS ENE  South Korea            NaN
# 8      Queenz Eye  24/10/2022    Big Mountain  South Korea            NaN
# 17    Hello Venus   9/05/2012        Fantagio  South Korea            NaN
# 18         TRACER   3/04/2022       Gleamedia  South Korea            NaN
# 22      7 O'clock  26/08/2014          Jungle    Hong Kong            NaN
# ...           ...         ...             ...          ...            ...
# 1744         ITZY  12/02/2019             JYP  South Korea            NaN
# 1747        ARIAZ  23/10/2019     Rising Star  South Korea            NaN
# 1748     Playback  25/06/2015         Coridel  South Korea            NaN
# 1758       IZ*ONE  29/10/2018  Off The Record  South Korea            NaN
# 1759         SNSD   4/08/2021       Good Luck  South Korea            NaN
#
#       Height  Weight Birthplace Other Group Former Group Gender
# 7        NaN     NaN        NaN         NaN          NaN      F
# 8        NaN     NaN      Seoul         NaN          NaN      F
# 17     166.0    47.0      Wonju         NaN          NaN      F
# 18       NaN     NaN        NaN         NaN          NaN      F
# 22       NaN     NaN        NaN         NaN          NaN      M
# ...      ...     ...        ...         ...          ...    ...
# 1744     NaN     NaN      Suwon         NaN          NaN      F
# 1747     NaN     NaN        NaN         NaN          NaN      F
# 1748     NaN     NaN        NaN         NaN          NaN      F
# 1758     NaN     NaN      Busan         NaN          NaN      F
# 1759   167.0    45.0     Goyang         NaN          NaN      F
#
# [520 rows x 16 columns]

# %% [markdown]
# 从输出结果来看，符合之前提到的行业常规，也就是`Stage Name`变量重复时`Group`并没有重复。为了验证这个规律，增加条件来筛选结果。

# %%
original_data[original_data.duplicated(subset=["Stage Name","Group"],keep=False)]
# Out:
#      Stage Name  Full Name Korean Name K Stage Name Date of Birth Group Debut  \
# 1453      Taeha  Yoo Taeha         유태하           태하     5/10/1995   NaN   NaN
# 1454      Taeha  Kim Taeha         김태하           태하     3/06/1998   NaN   NaN
#
#      Company      Country Second Country  Height  Weight Birthplace  \
# 1453     NaN  South Korea            NaN   162.0     NaN        NaN
# 1454     NaN  South Korea            NaN     NaN     NaN     Jeonju
#
#      Other Group Former Group Gender
# 1453         NaN   Berry Good      F
# 1454         NaN     MOMOLAND      F

# %% [markdown]
# 从输出结果来看，有两条记录存在`Stage Name`变量重复时`Group`也重复的情况。同时观察到后续分析需要的关键变量`Group`、`Debut`、`Company`也是缺失的，这不能提供有效数据，因此删除该重复值。

# %% [markdown]
# #### 评估不一致数据

# %% [markdown]
# 不一致数据可能存在于`Company`和`Group`变量中，需要查看是否存在多个不同值指代同一个公司或者组合的值。

# %%
pd.set_option('display.max_rows', None)
original_data["Company"].value_counts().sort_index()
# Out:
# 143                        3
# A team                    12
# A100                       3
# A2Z                        7
# AB Creative               14
# ADOR                       5
# ALLART                     5
# ANS                       13
# AO                         2
# ARA-LINE                   2
# ATTRAKT                    4
# About                      2
# All-S                      9
# Alseulbit                  5
# Amuse                      6
# Around Us                  5
# Asia Bridge                5
# Astory                     6
# BG                        14
# Barunson                   4
# Be:lift                    7
# Beat                       5
# Big Hit                   12
# Big Mountain               6
# Big Planet Made            3
# Blockberry                12
# Bluedot                    6
# Box                        4
# Brand New                 13
# Brave                     13
# C-JeS                      3
# C9                        21
# CHITWN                     5
# CJ E&M                    13
# CT                         7
# Chiko                      5
# Choeun                     7
# Choon                      5
# Chrome                     5
# Coridel                    5
# Cre.Ker                   11
# Cube                      37
# DOMA                       3
# DR                         4
# DSP                       30
# DWM                        6
# Dongyo                     5
# Double Kick                6
# DreamT                     4
# Dreamus                    5
# E Entertainment            8
# Elijah                     7
# Escrow                     5
# FC ENM                     9
# FENT                       7
# FNC                       52
# Fantagio                  20
# Fave                       3
# FirstOne                  10
# GF                         7
# GH                         8
# GKC                       10
# GLG                        4
# GNG                        4
# Gleamedia                  4
# Good Luck                  8
# H2                         5
# HO                         5
# Happy Face                11
# Happy Tribe| Universal     5
# Happyface                  5
# Hi-Up                      6
# Hunus                      1
# Hyper Rhythm               6
# IOK Company                7
# IST                        7
# Interpark                  7
# J Planet                   4
# J-FLO                      7
# J-Star                    10
# J-line                     5
# J. Tune                    7
# JT Corea                   9
# JTG                        9
# JYP                       56
# JYP| SidusHQ               9
# JZ Factory                 4
# Jellyfish                 21
# Jungle                    10
# KD                         4
# KITHEWHALE                 3
# KM                         7
# KQ                        25
# Keystone                   9
# Kiwi Pop                   7
# Kpop Live                  6
# Kyun Create                3
# LOEN                      15
# LPA                        7
# LUK                        7
# LiveWorks                  3
# Liz                        4
# MBK                       14
# MBK| Turbo Co.             2
# MLD                        6
# MNH                       13
# MODHAUS                   12
# MSH                        6
# MYSTIC                     7
# MYStar                     5
# Mafia                      4
# Majesty                    5
# Major9                     6
# Maroo                     13
# Mellow                     4
# Midas                      1
# Music K                    4
# Music Works                2
# My Doll                    8
# Mystic                     4
# NH                         4
# NH Media                   6
# NV                         5
# Nature Space               3
# New Planet                 5
# Nextlevel                  5
# ONO                        4
# OUI                        6
# Off The Record            16
# P NATION                   6
# Pascal                     4
# Plan A                    11
# Play M                     6
# Pledis                    29
# PocketDol                  9
# Polaris                    3
# RBW                       21
# RSVP                       6
# Rain                       7
# Rising Star                6
# Rolling                    2
# SAITEINMENT                5
# SD                         5
# SM                        58
# SM| Good| Shinhwa          6
# Shine E&M                  4
# Shofar                     2
# SidusHQ                    4
# Simtong                    3
# Source                     8
# Star Crew                  8
# Star Empire               21
# Star Planet                5
# Stardium                   6
# Starship                  44
# TOP Media                 25
# TR - Mellow                7
# TS                        26
# Umi                        5
# Unit Culture               5
# Universal                  7
# Vine                       5
# WKS ENE                    8
# WM                        15
# WYNN                       3
# WakeOne                    9
# Widmay                     6
# Winnerzone                 4
# Woollim                   37
# Wuzo                       7
# YES IM                     5
# YG                        41
# YMC                        7
# YNB                        7
# Yedang                    10
# Yuehua                    18
# Zoo                        5
# babaplay                   5
# iME                        6
# n.CH                      24
# Name: Company, dtype: int64

# %% [markdown]
# 从输出结果来看，没有多个不同值指代同一个公司的情况，不需要进行处理。

# %%
original_data["Group"].value_counts().sort_index()
# Out:
# (G)I-DLE             5
# 100%                 5
# 14U                 14
# 15&                  2
# 1TEAM                3
# 1the9                3
# 24K                  7
# 2EYES                4
# 2NE1                 4
# 2PM                  6
# 3YE                  3
# 4TEN                 4
# 4minute              5
# 7 O'clock            6
# 8TURN                8
# 9Muses               5
# A.C.E                5
# AB6IX                4
# ABLUE                6
# AIMERS               6
# ALICE                7
# ANS                  7
# APRIL                6
# AREAL                4
# ARGON                6
# ARIAZ                6
# ARTBEAT              7
# ASTRO                6
# ATBO                 7
# ATEEZ                8
# After School         5
# AoA                  4
# Apink                5
# Astin                7
# B.A.P                6
# B.I.G                5
# B.O.Y                2
# B1A4                 3
# BABYMONSTER          7
# BADKIZ               5
# BAE173               9
# BESTie               2
# BIGBANG              4
# BLACKPINK            4
# BLANK2Y              9
# BLITZERS             7
# BOTOPASS             8
# BTS                  7
# BVNDIT               5
# Berry Good           5
# Bigflo               5
# Billlie              7
# Blackswan            4
# Blady                5
# Bling Bling          6
# Block B              7
# Bolbbalgan4          2
# Bonus Baby           6
# Boyfriend            6
# Boys Republic        5
# Brave Girls          4
# Brown Eyed Girls     4
# BtoB                 7
# Busters              2
# CHECKMATE            5
# CIX                  5
# CLASS:y              7
# CLC                  5
# CNBLUE               4
# CRAVITY              9
# CRAXY                5
# CROSS GENE           6
# CSR                  7
# Cherry Bullet        7
# Cignature            7
# Ciipher              7
# Crayon Pop           5
# D-CRUNCH             9
# D1CE                 5
# DAY6                 5
# DIA                  7
# DKB                  9
# DRIPPIN              7
# DUSTIN               7
# Dal Shabet           4
# Davichi              2
# Dongkiz              5
# Dreamcatcher         7
# Dreamnote            6
# E'LAST               8
# ENHYPEN              7
# ENOi                 3
# EPEX                 8
# EXID                 5
# EXO                  9
# Everglow             6
# FANATICS             7
# FIFTY FIFTY          4
# FTISLAND             5
# Favorite             6
# Fiestar              5
# G-reyish             3
# GIDONGDAE            3
# GOT7                 7
# GWSN                 7
# Gate9                9
# Gfriend              3
# Ghost9               7
# Girl's Day           4
# Girlkind             5
# Girls' World         4
# Golden Child        10
# Good Day             1
# Gugudan              8
# H.U.B                5
# H1-KEY               4
# HISTORY              5
# HOT ISSUE            7
# HOTSHOT              5
# Hash Tag             7
# Hello Venus          6
# Hi-L                 6
# Highlight            5
# Highteen             4
# Hinapia              5
# Ho1iday              5
# Honey Popcorn        3
# Hot Blood Youth      5
# I.B.I                3
# ICHILLIN'            7
# ILY:1                6
# IM                   3
# IN2IT                7
# IRRIS                4
# ITZY                 5
# IVE                  6
# IZ                   4
# IZ*ONE               8
# Infinite             6
# JBJ                  3
# JBJ95                1
# JUST B               6
# JWiiver              7
# JYJ                  3
# KARA                 6
# KARD                 4
# KEEMBO               2
# KNK                  5
# Kep1er               9
# Kingdom              7
# LABOUM               4
# LE SSERAFIM          5
# LIGHTSUM             6
# LIMELIGHT            3
# LOONA               12
# LUNARSOLAR           4
# Ladies' Code         3
# Lapillus             6
# Limitless            4
# Lovelyz              8
# Luminous             4
# Lusty                5
# MAJORS               6
# MBLAQ                3
# MCND                 5
# MELODYDAY            4
# MIXX                 5
# MOMOLAND             6
# MONSTA X             6
# MONT                 3
# MY.st                5
# MYNAME               5
# Maka Maka            5
# Mamamoo              4
# Matilda              4
# Mirae                7
# N.Flying             5
# NATURE               7
# NCT                 20
# NINE.i              10
# NMIXX                6
# NU'EST               5
# Nature               2
# NewJeans             5
# Newkidd              7
# OMEGA X              9
# ONF                  6
# Oh My Girl           6
# Oneus                6
# Onewe                5
# OnlyOneOf            6
# P.O.P                6
# P1Harmony            6
# PENTAGON             9
# PRECIOUS             5
# PRIMROSE             2
# Pink Fantasy         8
# Pixy                 5
# Playback             5
# Pristin              6
# Pungdeng-E           3
# Purple Kiss          6
# Purplebeck           5
# Queenz Eye           6
# Rainbow              7
# Red Velvet           5
# RedSquare            2
# Rocket Punch         6
# Rockit Girl          2
# Romeo                7
# S#aFLA               4
# SECRET               3
# SECRET NUMBER        5
# SF9                  9
# SHINee               4
# SIGNAL               4
# SISTAR               4
# SNSD                 8
# SNUPER               6
# SPICA                2
# STAYC                6
# Saturday             5
# Seventeen           13
# Shinhwa              6
# Sonamoo              7
# Spectrum             3
# Stellar              4
# Stray Kids           8
# Super Junior        10
# Super Junior-M       2
# T-ara                4
# T1419                9
# TEMPEST              7
# TNX                  6
# TOO                 10
# TRACER               4
# TRCNG               10
# TRENDZ               7
# TRI.BE               7
# TVXQ                 2
# TXT                  5
# Tahiti               5
# Teen Top             5
# The Boyz            11
# TheEastLight         6
# Tiny-G               4
# Topp Dogg            5
# Treasure            12
# Twice                9
# Two X                4
# U-KISS               6
# UNI.T                5
# UNIQ                 5
# UNVS                 5
# UP10TION            10
# VARSITY             10
# VAV                  6
# VICTON               6
# VIVIZ                3
# VIXX                 6
# Verivery             7
# WEi                  6
# WINNER               4
# WJSN                10
# Wanna One            7
# Wassup               4
# We In The Zone       5
# We;Na                4
# Weeekly              6
# Weki Meki            8
# Wonder Girls         4
# X:IN                 5
# XEED                 3
# XUM                  3
# YOUNITE              9
# ZE:A                 9
# aespa                4
# bugAboo              6
# f(x)                 4
# fromis_9             8
# iKON                 6
# mimiimiii            1
# mimiirose            5
# miss A               4
# tripleS             12
# woo!ah!              5
# xikers              10
# Name: Group, dtype: int64

# %%
#恢复显示设置
pd.reset_option('display.max_rows')

# %% [markdown]
# 从输出结果来看，没有多个不同值指代同一个公司的情况，不需要进行处理。

# %% [markdown]
# #### 评估无效数据和错误数据

# %% [markdown]
# 可以通过DataFrame的`describe`方法对数值的统计信息进行了解。

# %%
original_data.describe()
# Out:
#            Height      Weight
# count  836.000000  566.000000
# mean   170.643541   57.224382
# std      7.805094   16.831308
# min    150.000000   38.000000
# 25%    164.000000   48.000000
# 50%    170.000000   57.000000
# 75%    177.000000   63.000000
# max    190.000000  170.000000

# %% [markdown]
# 直接获取的数据统计信息得出的是不区分性别的结果，可以看到`Weight`的最大值是170，这明显不符合普通偶像的身体状况，会对后续分析产生影响。
#
# 因此我们先提取出`Weight`大于100的观察值，进一步评估其含义。

# %%
original_data[original_data["Weight"]>=100]
# Out:
#      Stage Name       Full Name Korean Name K Stage Name Date of Birth  \
# 203       Dan-a  Park Seungyeon         박승연           단아    26/06/1993
# 290       Ellyn     Bang Sunhee         방선희           엘린    19/10/2002
# 392       Haena       Lee Haena         이해나           해나     2/06/1991
# 759          JK      Kim Jikang         김지강           지강    17/03/1998
# 992   Medic Jin       Bae Yujin         배유진          메딕진    25/08/1996
# 1198   Saebyeol    Han Saebyeol         한새별           새별    23/05/1996
# 1233      Semmi       Oh Heesun         오희선           세미    22/10/1995
# 1239  Seokcheol    Lee Seokchul         이석철           석철    11/01/2000
# 1410      Sun J     Jeon Heesun         전희선          썬제이    13/02/2001
# 1572     Xeheun      Lee Seheun         이세흔           세흔    11/07/1999
#
#              Group       Debut    Company      Country Second Country  Height  \
# 203        Matilda  18/03/2016        Box  South Korea            NaN     NaN
# 290       Girlkind  16/01/2018  Nextlevel  South Korea            NaN     NaN
# 392        Matilda  18/03/2016        Box  South Korea            NaN     NaN
# 759       Girlkind  16/01/2018  Nextlevel  South Korea            NaN     NaN
# 992       Girlkind  16/01/2018  Nextlevel  South Korea            NaN     NaN
# 1198       Matilda  18/03/2016        Box  South Korea            NaN     NaN
# 1233       Matilda  18/03/2016        Box  South Korea            NaN     NaN
# 1239  TheEastLight  15/11/2018   Stardium  South Korea            NaN     NaN
# 1410      Girlkind  16/01/2018  Nextlevel  South Korea            NaN     NaN
# 1572      Girlkind  16/01/2018  Nextlevel  South Korea            NaN     NaN
#
#       Weight Birthplace Other Group Former Group Gender
# 203    160.0        NaN         NaN          NaN      F
# 290    170.0        NaN         NaN          NaN      F
# 392    165.0        NaN         NaN          NaN      F
# 759    161.0        NaN         NaN          NaN      F
# 992    167.0        NaN         NaN          NaN      F
# 1198   168.0        NaN         NaN          NaN      F
# 1233   165.0        NaN         NaN          NaN      F
# 1239   170.0        NaN         NaN          NaN      M
# 1410   165.0        NaN         NaN          NaN      F
# 1572   162.0        NaN         NaN          NaN      F

# %% [markdown]
# 从输出结果的数值来看，这些数据更像是`Height`的数据，但是作为分析的关键变量，不能直接判断这些值就是`Height`的值，所以在后续步骤中删除`Weight`变量大于100的错误值。

# %% [markdown]
# 另外需要检查日期的逻辑性，查看出生日期`Date of Birth`是否在合理范围内。我们设定出道年龄不能小于10岁，不能大于80岁,也就是在1935年-2015年之间。

# %%
#截取出生日期年份
s1=pd.Series(original_data["Date of Birth"].str.slice(-4,10))
#将其转换为float类型（因为int不支持NaN的转换）
s1=s1.astype(float)
#筛选不在合理范围内的值
s1[(s1<1935)|(s1>2015)]
# Out:
# Series([], Name: Date of Birth, dtype: float64)

# %% [markdown]
# 输出结果为0，说明出生日期`Date of Birth`不存在错误数据。

# %% [markdown]
# 还需要检查出道年份`Debut`是否在出生日年份`Date of Birth`之后。

# %%
#截取出道日期年份
s2=pd.Series(original_data["Debut"].str.slice(-4,10))
#将其转换为float类型（因为int不支持NaN的转换）
s2=s2.astype(float)
#筛选不在合理范围内的值
s2[s2<s1]
# Out:
# 6       1900.0
# 27      2002.0
# 38      1900.0
# 152     1900.0
# 430     1900.0
# 432     2002.0
# 1136    1900.0
# 1181    1900.0
# 1190    1900.0
# Name: Debut, dtype: float64

# %% [markdown]
# 从输出结果来看，有9条记录的出道日期早于出生日期，是错误数据，后续步骤中需要删除这些数据。

# %% [markdown]
# ## 清理数据

# %% [markdown]
# 第三步将根据评估的结果进行数据清理。需要进行的数据清理包括：
#
# - 把`Company`列拆分并且只保留初次所属公司
# - 把`Date of Birth`变量的数据类型转换为日期时间类型
# - 把`Debut`变量的数据类型转换为日期时间类型
# - 把`Gender`变量的数据类型转换为`category`类型
# - 把`Full Name`、`Korean Name`、`K Stage Name`、`Second Country`、`Birthplace`、`Other Group`、`Former Group`列删除
# - 把`Group`变量缺失的观察值删除
# - 把`Date ofBirth`变量缺失的观察值删除
# - 把`Debut`变量缺失的观察值删除
# - 把`Company`变量缺失的观察值删除
# - 把`Weight`变量大于100的观察值删除
# - 把`Height`变量缺失的观察值用性别分组中位数填充
# - 把`Weight`变量缺失的观察值用性别分组中位数填充
# - 把`Stage Name`变量和`Group`变量同时重复的观察值删除
# - 把`Debut`变量早于`Date of Birth`的观察值删除
#
# 为了区分经过清理的数据和原始数据，创建新的变量`cleaned_data`，让它成为`original_data`的副本。之后的清理步骤将被运用在`cleaned_data`上。

# %%
cleaned_data=original_data.copy()
cleaned_data.head()
# Out:
#   Stage Name      Full Name Korean Name K Stage Name Date of Birth      Group  \
# 0      2Soul  Kim Younghoon         김영훈           이솔    10/09/1997  7 O'clock
# 1        A.M  Seong Hyunwoo         성현우          에이엠    31/12/1996  Limitless
# 2        Ace  Jang Wooyoung         장우영          에이스    28/08/1992        VAV
# 3       Aeji      Kwon Aeji         권애지           애지    25/10/1999   Hash Tag
# 4       AhIn       Lee Ahin         이아인           아인    27/09/1999   MOMOLAND
#
#         Debut      Company      Country Second Country  Height  Weight  \
# 0  26/08/2014       Jungle  South Korea            NaN   172.0    55.0
# 1   9/07/2019          ONO  South Korea            NaN   181.0    62.0
# 2  31/10/2015       A team  South Korea            NaN   177.0    63.0
# 3  11/10/2017          LUK  South Korea            NaN   163.0     NaN
# 4   9/11/2016  Double Kick  South Korea            NaN   160.0    44.0
#
#   Birthplace Other Group Former Group Gender
# 0        NaN         NaN          NaN      M
# 1        NaN         NaN          NaN      M
# 2        NaN         NaN          NaN      M
# 3      Daegu         NaN          NaN      F
# 4      Wonju         NaN          NaN      F

# %% [markdown]
# #### 把`Company`列拆分并且只保留初次所属公司：

# %%
#分列
cleaned_data["Company"].str.split("|",expand=True)

#给新产生的列命名
cleaned_data[["Company","C1","C2"]]=cleaned_data["Company"].str.split("|",expand=True)

#删除没用的列
cleaned_data=cleaned_data.drop(["C1","C2"],axis=1)

# %% [markdown]
# #### 把`Date of Birth`变量的数据类型转换为日期时间类型：

# %%
cleaned_data["Date of Birth"]=pd.to_datetime(cleaned_data["Date of Birth"])
cleaned_data["Date of Birth"]
# Out:
# 0      1997-10-09
# 1      1996-12-31
# 2      1992-08-28
# 3      1999-10-25
# 4      1999-09-27
#           ...
# 1773   1994-09-06
# 1774   2005-05-31
# 1775   1996-04-07
# 1776   1993-01-27
# 1777   1994-08-12
# Name: Date of Birth, Length: 1778, dtype: datetime64[ns]

# %% [markdown]
# #### 把`Debut`变量的数据类型转换为日期时间类型：

# %%
cleaned_data["Debut"]=pd.to_datetime(cleaned_data["Debut"])
cleaned_data["Debut"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File C:\Anaconda\lib\site-packages\pandas\_libs\tslib.pyx:534, in pandas._libs.tslib.array_to_datetime()
#
# File C:\Anaconda\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:257, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dateutil\parser\_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: month must be in 1..12: 0/01/1900
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File C:\Anaconda\lib\site-packages\pandas\_libs\tslib.pyx:545, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cleaned_data["Debut"]=pd.to_datetime(cleaned_data["Debut"])
#       2 cleaned_data["Debut"]
#
# File C:\Anaconda\lib\site-packages\pandas\core\tools\datetimes.py:883, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     881             result = result.tz_localize(tz)  # type: ignore[call-arg]
#     882 elif isinstance(arg, ABCSeries):
# --> 883     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     884     if not cache_array.empty:
#     885         result = arg.map(cache_array)
#
# File C:\Anaconda\lib\site-packages\pandas\core\tools\datetimes.py:195, in _maybe_cache(arg, format, cache, convert_listlike)
#     193 unique_dates = unique(arg)
#     194 if len(unique_dates) < len(arg):
# --> 195     cache_dates = convert_listlike(unique_dates, format)
#     196     cache_array = Series(cache_dates, index=unique_dates)
#     197     # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# File C:\Anaconda\lib\site-packages\pandas\core\tools\datetimes.py:401, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     399 assert format is None or infer_datetime_format
#     400 utc = tz == "utc"
# --> 401 result, tz_parsed = objects_to_datetime64ns(
#     402     arg,
#     403     dayfirst=dayfirst,
#     404     yearfirst=yearfirst,
#     405     utc=utc,
#     406     errors=errors,
#     407     require_iso8601=require_iso8601,
#     408     allow_object=True,
#     409 )
#     411 if tz_parsed is not None:
#     412     # We can take a shortcut since the datetime64 numpy array
#     413     # is in UTC
#     414     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File C:\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2193, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2191         return values.view("i8"), tz_parsed
#    2192     except (ValueError, TypeError):
# -> 2193         raise err
#    2195 if tz_parsed is not None:
#    2196     # We can take a shortcut since the datetime64 numpy array
#    2197     #  is in UTC
#    2198     # Return i8 values to denote unix timestamps
#    2199     return result.view("i8"), tz_parsed
#
# File C:\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2175, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2173 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2174 try:
# -> 2175     result, tz_parsed = tslib.array_to_datetime(
#    2176         data.ravel("K"),
#    2177         errors=errors,
#    2178         utc=utc,
#    2179         dayfirst=dayfirst,
#    2180         yearfirst=yearfirst,
#    2181         require_iso8601=require_iso8601,
#    2182         allow_mixed=allow_mixed,
#    2183     )
#    2184     result = result.reshape(data.shape, order=order)
#    2185 except ValueError as err:
#
# File C:\Anaconda\lib\site-packages\pandas\_libs\tslib.pyx:379, in pandas._libs.tslib.array_to_datetime()
#
# File C:\Anaconda\lib\site-packages\pandas\_libs\tslib.pyx:611, in pandas._libs.tslib.array_to_datetime()
#
# File C:\Anaconda\lib\site-packages\pandas\_libs\tslib.pyx:749, in pandas._libs.tslib._array_to_datetime_object()
#
# File C:\Anaconda\lib\site-packages\pandas\_libs\tslib.pyx:740, in pandas._libs.tslib._array_to_datetime_object()
#
# File C:\Anaconda\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:257, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dateutil\parser\_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#     654     ret = self._build_tzaware(ret, res, tzinfos)
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: month must be in 1..12: 0/01/1900

# %% [markdown]
# 这里遇到了将 `"0/01/1900"` 解析为日期时的问题。`"0/01/1900"` 可能表示缺失日期或占位符。我们先提取`Debut`值为`"0/01/1900"`的观察值进行评估。

# %%
cleaned_data[cleaned_data["Debut"]=="0/01/1900"]
# Out:
#      Stage Name                 Full Name Korean Name K Stage Name  \
# 6        Ahyeon               Jung Ahyeon         정아현           아현
# 38          Asa                 Enami Asa      에나미 아사           아사
# 152    Chiquita  Riracha Phondechaphiphat   리라차 폰데차피팟          치키타
# 430       Haram                Shin Haram         신하람           하람
# 1136    Pharita          Pharita Chaikong     파리따 차이콩          파리타
# 1181       Rora                  Lee Dain         이다인           로라
# 1190       Ruka                Kawai Ruka      카와이 루카           루카
#
#      Date of Birth        Group      Debut Company      Country  \
# 6       2007-11-04  BABYMONSTER  0/01/1900      YG  South Korea
# 38      2006-04-17  BABYMONSTER  0/01/1900      YG        Japan
# 152     2009-02-17  BABYMONSTER  0/01/1900      YG     Thailand
# 430     2007-10-17  BABYMONSTER  0/01/1900      YG  South Korea
# 1136    2005-08-26  BABYMONSTER  0/01/1900      YG     Thailand
# 1181    2008-05-08  BABYMONSTER  0/01/1900      YG  South Korea
# 1190    2002-03-20  BABYMONSTER  0/01/1900      YG        Japan
#
#      Second Country  Height  Weight Birthplace Other Group Former Group Gender
# 6               NaN     NaN     NaN        NaN         NaN          NaN      F
# 38              NaN     NaN     NaN        NaN         NaN          NaN      F
# 152             NaN     NaN     NaN        NaN         NaN          NaN      F
# 430             NaN     NaN     NaN        NaN         NaN          NaN      F
# 1136            NaN     NaN     NaN    Bangkok         NaN          NaN      F
# 1181            NaN     NaN     NaN        NaN         NaN          NaN      F
# 1190            NaN     NaN     NaN        NaN         NaN          NaN      F

# %% [markdown]
# 从输出结果来看，出道日`Debut`为`"0/01/1900"`的数据早于出生日期`Date of Birth`，这是不符合逻辑的，所以可以先将这些数据删除，再进行转换。

# %% [markdown]
# 删除错误值，并检查删除后错误值的个数：

# %%
cleaned_data=cleaned_data[cleaned_data["Debut"]!="0/01/1900"]

# %%
len(cleaned_data[cleaned_data["Debut"]=="0/01/1900"])
# Out:
# 0

# %% [markdown]
# 删除错误数据后，对`Debut`变量转换为日期时间类型：

# %%
cleaned_data["Debut"]=pd.to_datetime(cleaned_data["Debut"])
cleaned_data["Debut"]
# Out:
# 0      2014-08-26
# 1      2019-09-07
# 2      2015-10-31
# 3      2017-11-10
# 4      2016-09-11
#           ...
# 1773   2014-08-27
# 1774   2020-07-30
# 1775   2016-05-10
# 1776          NaT
# 1777   2013-07-03
# Name: Debut, Length: 1771, dtype: datetime64[ns]

# %% [markdown]
# #### 把`Gender`变量的数据类型转换为`category`类型：

# %%
cleaned_data["Gender"]=cleaned_data["Gender"].astype("category")
cleaned_data["Gender"]
# Out:
# 0       M
# 1       M
# 2       M
# 3       F
# 4       F
#        ..
# 1773    F
# 1774    F
# 1775    M
# 1776    M
# 1777    F
# Name: Gender, Length: 1771, dtype: category
# Categories (2, object): ['F', 'M']

# %% [markdown]
# #### 把`Full Name`、`Korean Name`、`K Stage Name`、`Second Country`、`Birthplace`、`Other Group`、`Former Group`列删除

# %%
cleaned_data=cleaned_data.drop(cleaned_data[["Full Name","Korean Name","K Stage Name","Second Country","Birthplace","Other Group","Former Group"]],axis=1)

# %%
cleaned_data.head()
# Out:
#   Stage Name Date of Birth      Group      Debut      Company      Country  \
# 0      2Soul    1997-10-09  7 O'clock 2014-08-26       Jungle  South Korea
# 1        A.M    1996-12-31  Limitless 2019-09-07          ONO  South Korea
# 2        Ace    1992-08-28        VAV 2015-10-31       A team  South Korea
# 3       Aeji    1999-10-25   Hash Tag 2017-11-10          LUK  South Korea
# 4       AhIn    1999-09-27   MOMOLAND 2016-09-11  Double Kick  South Korea
#
#    Height  Weight Gender
# 0   172.0    55.0      M
# 1   181.0    62.0      M
# 2   177.0    63.0      M
# 3   163.0     NaN      F
# 4   160.0    44.0      F

# %% [markdown]
# #### 把`Group`变量缺失的观察值删除，并检查删除后缺失值的个数:

# %%
cleaned_data.dropna(subset=["Group"],inplace=True)

# %%
cleaned_data["Group"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 把`Date of Birth`变量缺失的观察值删除，并检查删除后缺失值的个数:

# %%
cleaned_data.dropna(subset=["Date of Birth"],inplace=True)

# %%
cleaned_data["Date of Birth"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 把`Company`变量缺失的观察值删除，并检查删除后缺失值的个数:

# %%
cleaned_data.dropna(subset=["Company"],inplace=True)

# %%
cleaned_data["Company"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 把`Weight`变量大于100的观察值删除，并检查删除后缺失值的个数:

# %%
cleaned_data=cleaned_data[cleaned_data["Weight"]<100]

# %%
len(cleaned_data[cleaned_data["Weight"]>=100])
# Out:
# 0

# %% [markdown]
# #### 把`Height`变量缺失的观察值用性别分组中位数填充，并检查填充后是否存在缺失值：

# %%
cleaned_data["Height"]=cleaned_data.groupby('Gender')['Height'].transform(lambda x:x.fillna(x.median()))

# %%
cleaned_data["Height"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 把`Weight`变量缺失的观察值用性别分组中位数填充，并检查填充后是否存在缺失值：

# %%
cleaned_data['Weight']=cleaned_data.groupby('Gender')['Weight'].transform(lambda x:x.fillna(x.median()))

# %%
cleaned_data['Weight'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 把`Stage Name`变量和`Group`变量同时重复的观察值删除，并检查删除后同时重复的观察值：

# %%
cleaned_data.drop_duplicates(subset=['Stage Name','Group'],inplace=True)

# %%
len(cleaned_data[cleaned_data.duplicated(subset=["Stage Name","Group"],keep=False)])
# Out:
# 0

# %% [markdown]
# #### 把`Debut`变量早于`Date of Birth`的观察值删除，并检查删除后是否存在不合逻辑的观察值：

# %%
cleaned_data=cleaned_data[cleaned_data["Debut"]>cleaned_data["Date of Birth"]]

# %%
len(cleaned_data[cleaned_data["Debut"]<=cleaned_data["Date of Birth"]])
# Out:
# 0

# %% [markdown]
# ## 保存清理后的数据

# %% [markdown]
# 完成数据清理后，将干净整齐的数据保存到新文件里，文件名为"kpop_idols_cleaned.csv"。

# %%
cleaned_data.head()
# Out:
#    Stage Name Date of Birth      Group      Debut      Company      Country  \
# 0       2Soul    1997-10-09  7 O'clock 2014-08-26       Jungle  South Korea
# 1         A.M    1996-12-31  Limitless 2019-09-07          ONO  South Korea
# 2         Ace    1992-08-28        VAV 2015-10-31       A team  South Korea
# 4        AhIn    1999-09-27   MOMOLAND 2016-09-11  Double Kick  South Korea
# 14        Aki    2001-12-02     MAJORS 2021-09-03          ANS  South Korea
#
#     Height  Weight Gender
# 0    172.0    55.0      M
# 1    181.0    62.0      M
# 2    177.0    63.0      M
# 4    160.0    44.0      F
# 14   168.0    48.0      F

# %%
cleaned_data.to_csv("kpop_idols_cleaned.csv",index=False)

# %%
pd.read_csv("kpop_idols_cleaned.csv").head()
# Out:
#   Stage Name Date of Birth      Group       Debut      Company      Country  \
# 0      2Soul    1997-10-09  7 O'clock  2014-08-26       Jungle  South Korea
# 1        A.M    1996-12-31  Limitless  2019-09-07          ONO  South Korea
# 2        Ace    1992-08-28        VAV  2015-10-31       A team  South Korea
# 3       AhIn    1999-09-27   MOMOLAND  2016-09-11  Double Kick  South Korea
# 4        Aki    2001-12-02     MAJORS  2021-09-03          ANS  South Korea
#
#    Height  Weight Gender
# 0   172.0    55.0      M
# 1   181.0    62.0      M
# 2   177.0    63.0      M
# 3   160.0    44.0      F
# 4   168.0    48.0      F

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 512 entries, 0 to 1773
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Stage Name     512 non-null    object
#  1   Date of Birth  512 non-null    datetime64[ns]
#  2   Group          512 non-null    object
#  3   Debut          512 non-null    datetime64[ns]
#  4   Company        512 non-null    object
#  5   Country        512 non-null    object
#  6   Height         512 non-null    float64
#  7   Weight         512 non-null    float64
#  8   Gender         512 non-null    category
# dtypes: category(1), datetime64[ns](2), float64(2), object(4)
# memory usage: 36.6+ KB
